# %%
# linear algebra
import numpy as np

#Common Model Algorithms
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process
from xgboost import XGBClassifier

#Common Model Helpers
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics
from sklearn.model_selection import ShuffleSplit

#ignore warnings
import warnings
warnings.filterwarnings('ignore')
print('-'*25)

# data visualization
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style

# Algorithms
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB


#Configure Visualization Defaults
#%matplotlib inline = show plots in Jupyter Notebook browser
# %matplotlib inline
# mpl.style.use('ggplot')
# sns.set_style('white')
# Out:
# -------------------------

# %%
# Get the data
import pandas as pd

test_df = pd.read_csv("/content/test.csv")
df = pd.read_csv("/content/train.csv")
# df = pd.concat([train_df, test_df])

df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId',
#        'Name_wiki', 'Age_wiki', 'Hometown', 'Boarded', 'Destination',
#        'Lifeboat', 'Body', 'Class'], dtype=object)

# %%
print('Descriptive statistics of train_df:\n')
df.describe(include = 'all')
# Out:
# Descriptive statistics of train_df:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare  ... Embarked  \
# count   714.000000  891.000000  891.000000     891  891.000000  ...      889
# unique         NaN         NaN         NaN     681         NaN  ...        3
# top            NaN         NaN         NaN  347082         NaN  ...        S
# freq           NaN         NaN         NaN       7         NaN  ...      644
# mean     29.699118    0.523008    0.381594     NaN   32.204208  ...      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429  ...      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000  ...      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400  ...      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200  ...      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000  ...      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200  ...      NaN
#
#              WikiId                Name_wiki    Age_wiki  \
# count    889.000000                      889  887.000000
# unique          NaN                      889         NaN
# top             NaN  Braund, Mr. Owen Harris         NaN
# freq            NaN                        1         NaN
# mean     665.466817                      NaN   29.322063
# std      380.796997                      NaN   13.930089
# min        1.000000                      NaN    0.420000
# 25%      336.000000                      NaN   20.000000
# 50%      672.000000                      NaN   28.000000
# 75%      996.000000                      NaN   38.000000
# max     1314.000000                      NaN   74.000000
#
#                       Hometown      Boarded    Destination Lifeboat   Body  \
# count                      889          889            889      345     87
# unique                     437            4            234       22     87
# top     New York, New York, US  Southampton  New York City       15  175MB
# freq                        50          638            168       28      1
# mean                       NaN          NaN            NaN      NaN    NaN
# std                        NaN          NaN            NaN      NaN    NaN
# min                        NaN          NaN            NaN      NaN    NaN
# 25%                        NaN          NaN            NaN      NaN    NaN
# 50%                        NaN          NaN            NaN      NaN    NaN
# 75%                        NaN          NaN            NaN      NaN    NaN
# max                        NaN          NaN            NaN      NaN    NaN
#
#              Class
# count   889.000000
# unique         NaN
# top            NaN
# freq           NaN
# mean      2.307087
# std       0.837713
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       3.000000
# max       3.000000
#
# [11 rows x 21 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare  ... Embarked WikiId  \
# 0        0         A/5 21171   7.2500  ...        S  691.0
# 1        0          PC 17599  71.2833  ...        C   90.0
# 2        0  STON/O2. 3101282   7.9250  ...        S  865.0
# 3        0            113803  53.1000  ...        S  127.0
# 4        0            373450   8.0500  ...        S  627.0
# ..     ...               ...      ...  ...      ...    ...
# 886      0            211536  13.0000  ...        S  514.0
# 887      0            112053  30.0000  ...        S  137.0
# 888      2        W./C. 6607  23.4500  ...        S  910.0
# 889      0            111369  30.0000  ...        C   28.0
# 890      0            370376   7.7500  ...        Q  783.0
#
#                                       Name_wiki Age_wiki  \
# 0                       Braund, Mr. Owen Harris     22.0
# 1    Cumings, Mrs. Florence Briggs (née Thayer)     35.0
# 2                         Heikkinen, Miss Laina     26.0
# 3            Futrelle, Mrs. Lily May (née Peel)     35.0
# 4                      Allen, Mr. William Henry     35.0
# ..                                          ...      ...
# 886                     Montvila, Father Juozas     27.0
# 887                 Graham, Miss Margaret Edith     19.0
# 888             Johnston, Miss Catherine Nellie      7.0
# 889                       Behr, Mr. Karl Howell     26.0
# 890                      Dooley, Mr. Patrick J.     43.0
#
#                                Hometown      Boarded  \
# 0            Bridgerule, Devon, England  Southampton
# 1                New York, New York, US    Cherbourg
# 2                    Jyväskylä, Finland  Southampton
# 3           Scituate, Massachusetts, US  Southampton
# 4    Birmingham, West Midlands, England  Southampton
# ..                                  ...          ...
# 886              Gudinė, Lithuania [76]  Southampton
# 887          Greenwich, Connecticut, US  Southampton
# 888     Thornton Heath, London, England  Southampton
# 889              New York, New York, US    Cherbourg
# 890     Patrickswell, Limerick, Ireland   Queenstown
#
#                                  Destination Lifeboat Body Class
# 0    Qu'Appelle Valley, Saskatchewan, Canada      NaN  NaN   3.0
# 1                     New York, New York, US        4  NaN   1.0
# 2                              New York City      14?  NaN   3.0
# 3                Scituate, Massachusetts, US        D  NaN   1.0
# 4                              New York City      NaN  NaN   3.0
# ..                                       ...      ...  ...   ...
# 886             Worcester, Massachusetts, US      NaN  NaN   2.0
# 887               Greenwich, Connecticut, US        3  NaN   1.0
# 888              New London, Connecticut, US      NaN  NaN   3.0
# 889                   New York, New York, US        5  NaN   1.0
# 890                            New York City      NaN  NaN   3.0
#
# [891 rows x 21 columns]

# %%
df.shape
# Out:
# (891, 21)

# %%
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
#      WikiId                                       Name_wiki  Age_wiki  \
# 0     928.0                                Kelly, Mr. James      19.0
# 1    1297.0                              Wilkes, Mrs. Ellen      47.0
# 2     518.0                       Myles, Mr. Thomas Francis      63.0
# 3    1303.0                                Wirz, Mr. Albert      27.0
# 4     871.0  Hirvonen, Mrs. Helga Elisabeth (née Lindqvist)      22.0
# ..      ...                                             ...       ...
# 413  1227.0                              Spector, Mr. Woolf      23.0
# 414   229.0            and maid, Doña Fermina Oliva y Ocana      39.0
# 415  1169.0                     Sæther, Mr. Simon Sivertsen      43.0
# 416  1289.0                     Ware, Mr. Frederick William      34.0
# 417   702.0                 Butrus-Youssef, Master Makhkhul       4.0
#
#                          Hometown      Boarded                 Destination  \
# 0                Unknown, Ireland  Southampton               New York City
# 1     Penzance, Cornwall, England  Southampton             Akron, Ohio, US
# 2         Fermoy, Ireland[note 1]   Queenstown    Waban, Massachusetts, US
# 3              Uster, Switzerland  Southampton       Beloit, Wisconsin, US
# 4           Taalintehdas, Finland  Southampton  Monessen, Pennsylvania, US
# ..                            ...          ...                         ...
# 413               London, England  Southampton               New York City
# 414                 Madrid, Spain    Cherbourg      New York, New York, US
# 415  Skaun, Sør-Trøndelag, Norway  Southampton                          US
# 416    Greenwich, London, England  Southampton               New York City
# 417             Sar'al[81], Syria    Cherbourg       Detroit, Michigan, US
#
#     Lifeboat   Body  Class
# 0        NaN   70MB    3.0
# 1         16    NaN    3.0
# 2        NaN    NaN    2.0
# 3        NaN  131MB    3.0
# 4         15    NaN    3.0
# ..       ...    ...    ...
# 413      NaN    NaN    3.0
# 414        8    NaN    1.0
# 415      NaN   32MB    3.0
# 416      NaN    NaN    3.0
# 417        D    NaN    3.0
#
# [418 rows x 20 columns]

# %%
test_df.shape
# Out:
# (418, 20)

# %% [markdown]
# #**Wrangle, prepare, cleanse the data**

# %% [markdown]
# #Duplicate Records

# %%
#Find the number duplicate record
print('df - Number of duplicate Record:', df.duplicated().sum())

print('test_df - Number of duplicate Record:', test_df.duplicated().sum())
# Out:
# df - Number of duplicate Record: 0
# sub_df - Number of duplicate Record: 0

# %% [markdown]
# #Missing Values

# %%
#Find the number of null per each columns
print('Columns in df with null values:\n')
print(df)
print("-"*30)

print('Columns in sub_df with null values:\n')
print(test_df.isnull().sum())
print("-"*30)
# Out:
# Columns in df with null values:
#
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare  ... Embarked WikiId  \
# 0        0         A/5 21171   7.2500  ...        S  691.0
# 1        0          PC 17599  71.2833  ...        C   90.0
# 2        0  STON/O2. 3101282   7.9250  ...        S  865.0
# 3        0            113803  53.1000  ...        S  127.0
# 4        0            373450   8.0500  ...        S  627.0
# ..     ...               ...      ...  ...      ...    ...
# 886      0            211536  13.0000  ...        S  514.0
# 887      0            112053  30.0000  ...        S  137.0
# 888      2        W./C. 6607  23.4500  ...        S  910.0
# 889      0            111369  30.0000  ...        C   28.0
# 890      0            370376   7.7500  ...        Q  783.0
#
#                                       Name_wiki Age_wiki  \
# 0                       Braund, Mr. Owen Harris     22.0
# 1    Cumings, Mrs. Florence Briggs (née Thayer)     35.0
# 2                         Heikkinen, Miss Laina     26.0
# 3            Futrelle, Mrs. Lily May (née Peel)     35.0
# 4                      Allen, Mr. William Henry     35.0
# ..                                          ...      ...
# 886                     Montvila, Father Juozas     27.0
# 887                 Graham, Miss Margaret Edith     19.0
# 888             Johnston, Miss Catherine Nellie      7.0
# 889                       Behr, Mr. Karl Howell     26.0
# 890                      Dooley, Mr. Patrick J.     43.0
#
#                                Hometown      Boarded  \
# 0            Bridgerule, Devon, England  Southampton
# 1                New York, New York, US    Cherbourg
# 2                    Jyväskylä, Finland  Southampton
# 3           Scituate, Massachusetts, US  Southampton
# 4    Birmingham, West Midlands, England  Southampton
# ..                                  ...          ...
# 886              Gudinė, Lithuania [76]  Southampton
# 887          Greenwich, Connecticut, US  Southampton
# 888     Thornton Heath, London, England  Southampton
# 889              New York, New York, US    Cherbourg
# 890     Patrickswell, Limerick, Ireland   Queenstown
#
#                                  Destination Lifeboat Body Class
# 0    Qu'Appelle Valley, Saskatchewan, Canada      NaN  NaN   3.0
# 1                     New York, New York, US        4  NaN   1.0
# 2                              New York City      14?  NaN   3.0
# 3                Scituate, Massachusetts, US        D  NaN   1.0
# 4                              New York City      NaN  NaN   3.0
# ..                                       ...      ...  ...   ...
# 886             Worcester, Massachusetts, US      NaN  NaN   2.0
# 887               Greenwich, Connecticut, US        3  NaN   1.0
# 888              New London, Connecticut, US      NaN  NaN   3.0
# 889                   New York, New York, US        5  NaN   1.0
# 890                            New York City      NaN  NaN   3.0
#
# [891 rows x 21 columns]
# ------------------------------
# Columns in sub_df with null values:
#
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# WikiId           3
# Name_wiki        3
# Age_wiki         3
# Hometown         3
# Boarded          3
# Destination      3
# Lifeboat       261
# Body           375
# Class            3
# dtype: int64
# ------------------------------

# %%
combine = [df, test_df]

# %% [markdown]
# #Converting a categorical feature

# %%
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare  ... Embarked WikiId  \
# 0         A/5 21171   7.2500  ...        S  691.0
# 1          PC 17599  71.2833  ...        C   90.0
# 2  STON/O2. 3101282   7.9250  ...        S  865.0
# 3            113803  53.1000  ...        S  127.0
# 4            373450   8.0500  ...        S  627.0
#
#                                     Name_wiki Age_wiki  \
# 0                     Braund, Mr. Owen Harris     22.0
# 1  Cumings, Mrs. Florence Briggs (née Thayer)     35.0
# 2                       Heikkinen, Miss Laina     26.0
# 3          Futrelle, Mrs. Lily May (née Peel)     35.0
# 4                    Allen, Mr. William Henry     35.0
#
#                              Hometown      Boarded  \
# 0          Bridgerule, Devon, England  Southampton
# 1              New York, New York, US    Cherbourg
# 2                  Jyväskylä, Finland  Southampton
# 3         Scituate, Massachusetts, US  Southampton
# 4  Birmingham, West Midlands, England  Southampton
#
#                                Destination Lifeboat Body Class
# 0  Qu'Appelle Valley, Saskatchewan, Canada      NaN  NaN   3.0
# 1                   New York, New York, US        4  NaN   1.0
# 2                            New York City      14?  NaN   3.0
# 3              Scituate, Massachusetts, US        D  NaN   1.0
# 4                            New York City      NaN  NaN   3.0
#
# [5 rows x 21 columns]

# %%
grid = sns.FacetGrid(df, row='Pclass', col='Sex', height=2.2, aspect=1.6)
grid.map(plt.hist, 'Age', alpha=.5, bins=20)
grid.add_legend()
plt.show()

# %%
guess_ages = np.zeros((2,3))
guess_ages
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
for dataset in combine:
    for i in range(0, 2):
        for j in range(0, 3):
            guess_df = dataset[(dataset['Sex'] == i) & (dataset['Pclass'] == j+1)]['Age'].dropna()

            # age_mean = guess_df.mean()
            # age_std = guess_df.std()
            # age_guess = rnd.uniform(age_mean - age_std, age_mean + age_std)

            age_guess = guess_df.median()

            # Convert random age float to nearest .5 age
            guess_ages[i,j] = int( age_guess/0.5 + 0.5 ) * 0.5

    for i in range(0, 2):
        for j in range(0, 3):
            dataset.loc[ (dataset.Age.isnull()) & (dataset.Sex == i) & (dataset.Pclass == j+1),'Age'] = guess_ages[i,j]

    dataset['Age'] = dataset['Age'].astype(int)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1      0
# 2                             Heikkinen, Miss. Laina    1   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1      0
# 4                           Allen, Mr. William Henry    0   35      0      0
#
#              Ticket     Fare  ... Embarked WikiId  \
# 0         A/5 21171   7.2500  ...        S  691.0
# 1          PC 17599  71.2833  ...        C   90.0
# 2  STON/O2. 3101282   7.9250  ...        S  865.0
# 3            113803  53.1000  ...        S  127.0
# 4            373450   8.0500  ...        S  627.0
#
#                                     Name_wiki Age_wiki  \
# 0                     Braund, Mr. Owen Harris     22.0
# 1  Cumings, Mrs. Florence Briggs (née Thayer)     35.0
# 2                       Heikkinen, Miss Laina     26.0
# 3          Futrelle, Mrs. Lily May (née Peel)     35.0
# 4                    Allen, Mr. William Henry     35.0
#
#                              Hometown      Boarded  \
# 0          Bridgerule, Devon, England  Southampton
# 1              New York, New York, US    Cherbourg
# 2                  Jyväskylä, Finland  Southampton
# 3         Scituate, Massachusetts, US  Southampton
# 4  Birmingham, West Midlands, England  Southampton
#
#                                Destination Lifeboat Body Class
# 0  Qu'Appelle Valley, Saskatchewan, Canada      NaN  NaN   3.0
# 1                   New York, New York, US        4  NaN   1.0
# 2                            New York City      14?  NaN   3.0
# 3              Scituate, Massachusetts, US        D  NaN   1.0
# 4                            New York City      NaN  NaN   3.0
#
# [5 rows x 21 columns]

# %% [markdown]
# #Handle missing value - categorical variable

# %%
#Find the value count of train_df['Embarked']
print('Value count of Embarked variable in train_df:\n')
print(df['Embarked'].value_counts())
print("-"*30)

# Find the mode of train_df['Embarked']
freq_port = df.Embarked.dropna().mode()[0]
print('Mode of Embarked variable in train_df: ',freq_port)
# Out:
# Value count of Embarked variable in train_df:
#
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
# ------------------------------
# Mode of Embarked variable in train_df:  S

# %%
#Fill the null value of Embarked with the most common occurance

for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].fillna(freq_port)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1      0
# 2                             Heikkinen, Miss. Laina    1   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1      0
# 4                           Allen, Mr. William Henry    0   35      0      0
#
#              Ticket     Fare  ... Embarked WikiId  \
# 0         A/5 21171   7.2500  ...        S  691.0
# 1          PC 17599  71.2833  ...        C   90.0
# 2  STON/O2. 3101282   7.9250  ...        S  865.0
# 3            113803  53.1000  ...        S  127.0
# 4            373450   8.0500  ...        S  627.0
#
#                                     Name_wiki Age_wiki  \
# 0                     Braund, Mr. Owen Harris     22.0
# 1  Cumings, Mrs. Florence Briggs (née Thayer)     35.0
# 2                       Heikkinen, Miss Laina     26.0
# 3          Futrelle, Mrs. Lily May (née Peel)     35.0
# 4                    Allen, Mr. William Henry     35.0
#
#                              Hometown      Boarded  \
# 0          Bridgerule, Devon, England  Southampton
# 1              New York, New York, US    Cherbourg
# 2                  Jyväskylä, Finland  Southampton
# 3         Scituate, Massachusetts, US  Southampton
# 4  Birmingham, West Midlands, England  Southampton
#
#                                Destination Lifeboat Body Class
# 0  Qu'Appelle Valley, Saskatchewan, Canada      NaN  NaN   3.0
# 1                   New York, New York, US        4  NaN   1.0
# 2                            New York City      14?  NaN   3.0
# 3              Scituate, Massachusetts, US        D  NaN   1.0
# 4                            New York City      NaN  NaN   3.0
#
# [5 rows x 21 columns]

# %%
#Converting categorical feature to numeric

for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].map({"S": 1, "C": 2, "Q": 3})

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1      0
# 2                             Heikkinen, Miss. Laina    1   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1      0
# 4                           Allen, Mr. William Henry    0   35      0      0
#
#              Ticket     Fare  ... Embarked  WikiId  \
# 0         A/5 21171   7.2500  ...        1   691.0
# 1          PC 17599  71.2833  ...        2    90.0
# 2  STON/O2. 3101282   7.9250  ...        1   865.0
# 3            113803  53.1000  ...        1   127.0
# 4            373450   8.0500  ...        1   627.0
#
#                                     Name_wiki Age_wiki  \
# 0                     Braund, Mr. Owen Harris     22.0
# 1  Cumings, Mrs. Florence Briggs (née Thayer)     35.0
# 2                       Heikkinen, Miss Laina     26.0
# 3          Futrelle, Mrs. Lily May (née Peel)     35.0
# 4                    Allen, Mr. William Henry     35.0
#
#                              Hometown      Boarded  \
# 0          Bridgerule, Devon, England  Southampton
# 1              New York, New York, US    Cherbourg
# 2                  Jyväskylä, Finland  Southampton
# 3         Scituate, Massachusetts, US  Southampton
# 4  Birmingham, West Midlands, England  Southampton
#
#                                Destination Lifeboat Body Class
# 0  Qu'Appelle Valley, Saskatchewan, Canada      NaN  NaN   3.0
# 1                   New York, New York, US        4  NaN   1.0
# 2                            New York City      14?  NaN   3.0
# 3              Scituate, Massachusetts, US        D  NaN   1.0
# 4                            New York City      NaN  NaN   3.0
#
# [5 rows x 21 columns]

# %%
for dataset in combine:
    dataset['Fare'].fillna(dataset['Fare'].dropna().mean(), inplace=True)
    dataset['Fare'] = dataset['Fare'].astype(np.int64)

# %%
for dataset in combine:
    dataset['Title']  = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
pd.crosstab(df["Title"], test_df['Sex'])
# Out:
# Sex       0   1
# Title
# Don       1   0
# Dr        3   0
# Master   14   9
# Miss     64  37
# Mme       1   0
# Mr      145  83
# Mrs      37  21
# Rev       1   2

# %%
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

# %%
for dataset in combine:
    dataset['Title'] = dataset['Title'].map({"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5})
    dataset['Title'] = dataset['Title'].fillna(0)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1      0
# 2                             Heikkinen, Miss. Laina    1   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1      0
# 4                           Allen, Mr. William Henry    0   35      0      0
#
#              Ticket  Fare  ... WikiId  \
# 0         A/5 21171     7  ...  691.0
# 1          PC 17599    71  ...   90.0
# 2  STON/O2. 3101282     7  ...  865.0
# 3            113803    53  ...  127.0
# 4            373450     8  ...  627.0
#
#                                     Name_wiki  Age_wiki  \
# 0                     Braund, Mr. Owen Harris      22.0
# 1  Cumings, Mrs. Florence Briggs (née Thayer)      35.0
# 2                       Heikkinen, Miss Laina      26.0
# 3          Futrelle, Mrs. Lily May (née Peel)      35.0
# 4                    Allen, Mr. William Henry      35.0
#
#                              Hometown      Boarded  \
# 0          Bridgerule, Devon, England  Southampton
# 1              New York, New York, US    Cherbourg
# 2                  Jyväskylä, Finland  Southampton
# 3         Scituate, Massachusetts, US  Southampton
# 4  Birmingham, West Midlands, England  Southampton
#
#                                Destination Lifeboat Body Class Title
# 0  Qu'Appelle Valley, Saskatchewan, Canada      NaN  NaN   3.0     1
# 1                   New York, New York, US        4  NaN   1.0     3
# 2                            New York City      14?  NaN   3.0     2
# 3              Scituate, Massachusetts, US        D  NaN   1.0     3
# 4                            New York City      NaN  NaN   3.0     1
#
# [5 rows x 22 columns]

# %%
for dataset in combine:
    dataset['Deck'] = dataset['Cabin'].str.slice(0,1)
    dataset['Deck'] = dataset['Deck'].map({"A": 1, "B": 2, "C": 3, "D": 4, "E": 5, "F":6,"G":7, "T":8})
    dataset['Deck'] = dataset['Deck'].fillna(0)
    dataset['Deck'] = dataset['Deck'].astype(np.int64)

# %%
#Find the number of null per each columns
print('Columns in df with null values:\n')
print(df.isnull().sum())
print("-"*30)

print('Columns in sub_df with null values:\n')
print(test_df.isnull().sum())
print("-"*30)
# Out:
# Columns in df with null values:
#
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# WikiId           2
# Name_wiki        2
# Age_wiki         4
# Hometown         2
# Boarded          2
# Destination      2
# Lifeboat       546
# Body           804
# Class            2
# Title            0
# Deck             0
# dtype: int64
# ------------------------------
# Columns in sub_df with null values:
#
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# WikiId           3
# Name_wiki        3
# Age_wiki         3
# Hometown         3
# Boarded          3
# Destination      3
# Lifeboat       261
# Body           375
# Class            3
# Title            0
# Deck             0
# dtype: int64
# ------------------------------

# %%
for dataset in combine:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1

# %%
for dataset in combine:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1
